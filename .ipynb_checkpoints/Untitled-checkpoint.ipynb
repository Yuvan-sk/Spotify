# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
from sqlalchemy import create_engine
import sys
import pdfkit
from pdf_mail import sendpdf
import time
import schedule

# %%
spotify_client_id = "f0a222565c854f32b07dc713ec215d70"
spotify_client_secret = "0b853a5a3cb44039835e3b7bef9ad8eb"
spotify_redirect_url = "http://localhost:8000/redirect/"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=spotify_client_id,
                                                   client_secret=spotify_client_secret,
                                                   redirect_uri=spotify_redirect_url,
                                                   scope="user-read-recently-played"))
recently_played = sp.current_user_recently_played(limit=10)

#if the length of recently_played is 0 for some reason just exit the program
if len(recently_played) ==0:
    sys.exit("No results recieved from Spotify")

# %%
song_list = []
for row in recently_played['items']:
    song_name = row['track']['name']
    album_release_date = row['track']['album']['release_date']
    artist_name= row['track']['album']['artists'][0]['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_time_played = row['played_at']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'name':song_name,'release_date':album_release_date,'artist_name':artist_name,'duration_ms':song_duration,
                    'url':song_url,'popularity':song_popularity,'date_time_played':song_time_played,'artist_id':artist_id}
    song_list.append(song_element)
song_df = pd.DataFrame.from_dict(song_list)
song_df['date_time_played'] = pd.to_datetime(song_df['date_time_played'])
song_df['date_time_played'] = song_df['date_time_played'].dt.tz_convert('Asia/Kolkata')
song_df['date_time_played'] = song_df['date_time_played'].astype(str).str[:-7]
song_df['date_time_played'] = pd.to_datetime(song_df['date_time_played'])
song_df = song_df[['name','release_date','artist_name','duration_ms','url','popularity','date_time_played','artist_id']]
song_df
# Out:
#                                                 name release_date  \
# 0                            So Baby (From "Doctor")   2021-02-25
# 1                                       Can I Get It   2021-11-19
# 2                                       Can I Get It   2021-11-19
# 3                                              Pepas   2021-10-01
# 4                                            Shivers   2021-10-29
# 5                                         Heat Waves   2020-08-06
# 6                            Cold Heart - PNAU Remix   2021-10-22
# 7  All Too Well (10 Minute Version) (Taylor's Ver...   2021-11-12
# 8                  INDUSTRY BABY (feat. Jack Harlow)   2021-09-17
# 9                                          Oh My God   2021-11-19
#
#            artist_name  duration_ms  \
# 0  Anirudh Ravichander       252631
# 1                Adele       210384
# 2                Adele       210384
# 3              Farruko       287120
# 4           Ed Sheeran       207853
# 5        Glass Animals       238805
# 6           Elton John       202735
# 7         Taylor Swift       613026
# 8            Lil Nas X       212352
# 9                Adele       225148
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0t0mHozF8Xsif9w...          66
# 1  https://open.spotify.com/track/6w8ZPYdnGajyfPd...          85
# 2  https://open.spotify.com/track/6w8ZPYdnGajyfPd...          85
# 3  https://open.spotify.com/track/2B4GHvToeLTOBB4...          84
# 4  https://open.spotify.com/track/50nfwKoDiSYg8zO...          92
# 5  https://open.spotify.com/track/02MWAaffLxlfxAU...          91
# 6  https://open.spotify.com/track/7rglLriMNBPAyuJ...          85
# 7  https://open.spotify.com/track/5enxwA8aAbwZbf5...          93
# 8  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...          90
# 9  https://open.spotify.com/track/3Kkjo3cT83cw09V...          87
#
#          date_time_played               artist_id
# 0 2021-11-24 17:52:55.257  4zCH9qm4R2DADamUHMCa6O
# 1 2021-11-24 17:47:11.296  4dpARuHxo51G3z768sgnrY
# 2 2021-11-22 16:37:51.211  4dpARuHxo51G3z768sgnrY
# 3 2021-11-22 16:34:19.937  329e4yvIujISKGKz1BZZbO
# 4 2021-11-22 16:29:32.728  6eUKZXaKkcviH0Ku9w2n3V
# 5 2021-11-22 16:25:34.566  4yvcSjfu4PC0CYQyLy4wSq
# 6 2021-11-22 16:21:34.431  3PhoLpVuITZKcymswpck5b
# 7 2021-11-22 16:18:11.784  06HL4z0CvFAxyc27GXpf02
# 8 2021-11-22 16:07:58.246  7jVv8c5Fj3E9VhNjxT4snq
# 9 2021-11-22 16:04:25.809  4dpARuHxo51G3z768sgnrY

# %%
song_df.to_csv(r"C:\Users\yuvan shankar\Downloads\spotify\recommendation\recently_10.csv",index=False)

# %%
spotify_client_id = "f0a222565c854f32b07dc713ec215d70"
spotify_client_secret = "0b853a5a3cb44039835e3b7bef9ad8eb"
spotify_redirect_url = "http://localhost:8000/redirect/"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=spotify_client_id,
                                                   client_secret=spotify_client_secret,
                                                   redirect_uri=spotify_redirect_url))
df_1= pd.read_csv("recently_10.csv")
df_1
# Out:
#                                                 name release_date  \
# 0                            So Baby (From "Doctor")   2021-02-25
# 1                                       Can I Get It   2021-11-19
# 2                                       Can I Get It   2021-11-19
# 3                                              Pepas   2021-10-01
# 4                                            Shivers   2021-10-29
# 5                                         Heat Waves   2020-08-06
# 6                            Cold Heart - PNAU Remix   2021-10-22
# 7  All Too Well (10 Minute Version) (Taylor's Ver...   2021-11-12
# 8                  INDUSTRY BABY (feat. Jack Harlow)   2021-09-17
# 9                                          Oh My God   2021-11-19
#
#            artist_name  duration_ms  \
# 0  Anirudh Ravichander       252631
# 1                Adele       210384
# 2                Adele       210384
# 3              Farruko       287120
# 4           Ed Sheeran       207853
# 5        Glass Animals       238805
# 6           Elton John       202735
# 7         Taylor Swift       613026
# 8            Lil Nas X       212352
# 9                Adele       225148
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0t0mHozF8Xsif9w...          66
# 1  https://open.spotify.com/track/6w8ZPYdnGajyfPd...          85
# 2  https://open.spotify.com/track/6w8ZPYdnGajyfPd...          85
# 3  https://open.spotify.com/track/2B4GHvToeLTOBB4...          84
# 4  https://open.spotify.com/track/50nfwKoDiSYg8zO...          92
# 5  https://open.spotify.com/track/02MWAaffLxlfxAU...          91
# 6  https://open.spotify.com/track/7rglLriMNBPAyuJ...          85
# 7  https://open.spotify.com/track/5enxwA8aAbwZbf5...          93
# 8  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...          90
# 9  https://open.spotify.com/track/3Kkjo3cT83cw09V...          87
#
#           date_time_played               artist_id
# 0  2021-11-24 17:52:55.257  4zCH9qm4R2DADamUHMCa6O
# 1  2021-11-24 17:47:11.296  4dpARuHxo51G3z768sgnrY
# 2  2021-11-22 16:37:51.211  4dpARuHxo51G3z768sgnrY
# 3  2021-11-22 16:34:19.937  329e4yvIujISKGKz1BZZbO
# 4  2021-11-22 16:29:32.728  6eUKZXaKkcviH0Ku9w2n3V
# 5  2021-11-22 16:25:34.566  4yvcSjfu4PC0CYQyLy4wSq
# 6  2021-11-22 16:21:34.431  3PhoLpVuITZKcymswpck5b
# 7  2021-11-22 16:18:11.784  06HL4z0CvFAxyc27GXpf02
# 8  2021-11-22 16:07:58.246  7jVv8c5Fj3E9VhNjxT4snq
# 9  2021-11-22 16:04:25.809  4dpARuHxo51G3z768sgnrY

# %%
qwe=list(df_1.artist_id)
qwe
# Out:
# ['4zCH9qm4R2DADamUHMCa6O',
#  '4dpARuHxo51G3z768sgnrY',
#  '4dpARuHxo51G3z768sgnrY',
#  '329e4yvIujISKGKz1BZZbO',
#  '6eUKZXaKkcviH0Ku9w2n3V',
#  '4yvcSjfu4PC0CYQyLy4wSq',
#  '3PhoLpVuITZKcymswpck5b',
#  '06HL4z0CvFAxyc27GXpf02',
#  '7jVv8c5Fj3E9VhNjxT4snq',
#  '4dpARuHxo51G3z768sgnrY']

# %%
results = sp.recommendations(seed_artists=[qwe[0]],limit=10)
if len(results) ==0:
    sys.exit("No results recieved from Spotify")

# %%
artist_list = []
for track in results['tracks']:
    song_name = track['name']
    artist_name= track['album']['artists'][0]['name']
    artist_element = {'song_name':song_name,'artist_name':artist_name}
    artist_list.append(artist_element)
df = pd.DataFrame.from_dict(artist_list)
df
# Out:
#                                  song_name          artist_name
# 0                                    Uyire          Ankit Menon
# 1                            Gaali Vaaluga  Anirudh Ravichander
# 2                           Paartha Mudhal       Harris Jayaraj
# 3                               Venmathiye      Various Artists
# 4                                   Vaanam   Yuvan Shankar Raja
# 5                               Neruppu Da   Santhosh Narayanan
# 6                   Idhayathai Yedho Ondru       Harris Jayaraj
# 7                    Shree Hanuman Chalisa            Hariharan
# 8    Enakenna Yaarum Illaye (From "Aakko")  Anirudh Ravichander
# 9  Mandhuloda (From "Sridevi Soda Center")          Mani Sharma
